# %% [markdown]
# #### import

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import matplotlib.pyplot as plt

np.random.seed(0)
tf.random.set_seed(0)

# %% [markdown]
# #### 학습결과 시각화 함수

# %%
# epoch별 loss의 변화를 시각화하는 함수
def plot_loss(epochs, history):
    """
    학습 loss를 시각화 하는 함수
    """
    plt.figure(figsize=(8,7))
    plt.plot(range(1, epochs+1), history.history['loss'], label='Train Loss')
    plt.plot(range(1, epochs+1), history.history['val_loss'], label='Validation Loss')
    plt.title("Loss")
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# %%
# epoch별 accuracy의 변화를 시각화하는 함수
def plot_accuracy(epochs, history):
    """
    학습 Accuracy를 시각화 하는 함수
    """
    plt.figure(figsize=(8,7))
    plt.plot(range(1, epochs+1), history.history['accuracy'], label='Train Accuracy')
    plt.plot(range(1, epochs+1), history.history['val_accuracy'], 
                                                 label='Validation Accuracy')
    plt.title("Accuracy")
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

# %% [markdown]
# #### 데이터 로딩
# - MNIST 숫자 손글씨 데이터

# %%
(train_image, train_label), (test_image, test_label) = keras.datasets.mnist.load_data()

# %%
train_image.shape, test_image.shape
# Out:
# ((60000, 28, 28), (10000, 28, 28))

# %% [markdown]
# #### 하이퍼파라미터 변수 정의

# %%
# 하이퍼파라미터 변수
LEARNING_RATE = 0.001  #학습율 - optimizer에 설정
N_EPOCHS = 20   # 에폭수
N_BATCHS = 100  # batch size

# train/test 데이터의 개수를 변수 정의
N_TRAIN = train_image.shape[0]
N_TEST = test_image.shape[0]

# %% [markdown]
# #### 전처리
# - image : 0 ~ 1 사이의 값으로 정규화
# - label : one hot encoding (다중분류문제이므로)

# %%
train_image.dtype
# Out:
# dtype('uint8')

# %%
X_train = (train_image).astype("float32")/255.0
X_test = (test_image).astype('float32')/255.0

# %%
y_train = keras.utils.to_categorical(train_label)
y_test = keras.utils.to_categorical(test_label)

# %%
np.min(X_train), np.max(X_train), np.min(X_test), np.max(X_test)
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
y_train.shape, y_test.shape
# Out:
# ((60000, 10), (10000, 10))

# %% [markdown]
# #### Dataset 생성

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))\
                               .shuffle(N_TRAIN)\
                               .batch(N_BATCHS, drop_remainder=True)

test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(N_BATCHS)

# %% [markdown]
# # 모델의 크기 변경

# %% [markdown]
# #### 작은 모델

# %%
def create_small_model():
    #모델생성
    model = keras.Sequential()
    # 레이어 추가 - Hidden
    model.add(layers.Flatten(input_shape=(28,28)))
    model.add(layers.Dense(units=1, activation='relu'))
    # 출력레이어 - 다중분류: unit수-클래스수, activation-softmax
    model.add(layers.Dense(units=10, activation='softmax'))
    return model

# %%
# 모델 생성, 컴파일
small_model =  create_small_model()
# 다중분류: loss-categorical_crossentropy
small_model.compile(optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE),
                    loss='categorical_crossentropy',
                    metrics=['accuracy'])

# %%
small_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 1)                 785
#
#  dense_1 (Dense)             (None, 10)                20
#
# =================================================================
# Total params: 805
# Trainable params: 805
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(small_model, show_shapes=True)

# %%
hist = small_model.fit(train_dataset, epochs=N_EPOCHS, 
                       validation_data=test_dataset)
# Out:
# Epoch 1/20
# 600/600 [==============================] - 2s 2ms/step - loss: 2.0981 - accuracy: 0.1922 - val_loss: 1.9758 - val_accuracy: 0.2240
# Epoch 2/20
# 600/600 [==============================] - 1s 2ms/step - loss: 1.9096 - accuracy: 0.2301 - val_loss: 1.8601 - val_accuracy: 0.2478
# Epoch 3/20
# 600/600 [==============================] - 1s 1ms/step - loss: 1.8248 - accuracy: 0.2455 - val_loss: 1.7992 - val_accuracy: 0.2550
# Epoch 4/20
# 600/600 [==============================] - 1s 2ms/step - loss: 1.7779 - accuracy: 0.2595 - val_loss: 1.7630 - val_accuracy: 0.2738
# Epoch 5/20
# 600/600 [==============================] - 1s 2ms/step - loss: 1.7476 - accuracy: 0.2717 - val_loss: 1.7367 - val_accuracy: 0.2688
# Epoch 6/20
# 600/600 [==============================] - 1s 2ms/step - loss: 1.7259 - accuracy: 0.2754 - val_loss: 1.7191 - val_accuracy: 0.2709
# Epoch 7/20
# 600/600 [==============================] - 1s 1ms/step - loss: 1.7098 - accuracy: 0.2796 - val_loss: 1.7028 - val_accuracy: 0.2833
# Epoch 8/20
# 600/600 [==============================] - 1s 2ms/step - loss: 1.6979 - accuracy: 0.2796 - val_loss: 1.6933 - val_accuracy: 0.2763
# Epoch 9/20
# 600/600 [==============================] - 1s 2ms/step - loss: 1.6882 - accuracy: 0.2859 - val_loss: 1.6854 - val_accuracy: 0.2932
# Epoch 10/20
# 600/600 [==============================] - 1s 1ms/step - loss: 1.6813 - accuracy: 0.2872 - val_loss: 1.6783 - val_accuracy: 0.2947
# Epoch 11/20
# 600/600 [==============================] - 1s 2ms/step - loss: 1.6752 - accuracy: 0.2891 - val_loss: 1.6739 - val_accuracy: 0.2932
# Epoch 12/20
# 600/600 [==============================] - 1s 1ms/step - loss: 1.6700 - accuracy: 0.2894 - val_loss: 1.6692 - val_accuracy: 0.2958
# Epoch 13/20
# 600/600 [==============================] - 1s 1ms/step - loss: 1.6656 - accuracy: 0.2909 - val_loss: 1.6660 - val_accuracy: 0.2946
# Epoch 14/20
# 600/600 [==============================] - 1s 2ms/step - loss: 1.6619 - accuracy: 0.2919 - val_loss: 1.6636 - val_accuracy: 0.2936
# Epoch 15/20
# 600/600 [==============================] - 1s 2ms/step - loss: 1.6586 - accuracy: 0.2925 - val_loss: 1.6600 - val_accuracy: 0.2976
# Epoch 16/20
# 600/600 [==============================] - 1s 2ms/step - loss: 1.6555 - accuracy: 0.2955 - val_loss: 1.6584 - val_accuracy: 0.2941
# Epoch 17/20
# 600/600 [==============================] - 1s 2ms/step - loss: 1.6523 - accuracy: 0.3035 - val_loss: 1.6541 - val_accuracy: 0.3085
# Epoch 18/20
# 600/600 [==============================] - 1s 1ms/step - loss: 1.6493 - accuracy: 0.3113 - val_loss: 1.6510 - val_accuracy: 0.3049
# Epoch 19/20
# 600/600 [==============================] - 1s 1ms/step - loss: 1.6452 - accuracy: 0.3256 - val_loss: 1.6483 - val_accuracy: 0.3402
# Epoch 20/20
# 600/600 [==============================] - 1s 1ms/step - loss: 1.6390 - accuracy: 0.3369 - val_loss: 1.6405 - val_accuracy: 0.3074

# %%
plot_loss(N_EPOCHS, hist)

# %%
plot_accuracy(N_EPOCHS, hist)

# %% [markdown]
# #### 모델의 크기를 크게

# %%
def create_bigger_model():
    model = keras.Sequential()
    #은닉층
    model.add(layers.Flatten(input_shape=(28,28)))
    model.add(layers.Dense(units=256, activation='relu'))
    model.add(layers.Dense(units=256, activation='relu'))
    model.add(layers.Dense(units=128, activation='relu'))
    model.add(layers.Dense(units=128, activation='relu'))
    #출력층
    model.add(layers.Dense(units=10, activation='softmax'))
    return model

# %%
bigger_model = create_bigger_model()
bigger_model.compile(optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE),
                     loss='categorical_crossentropy',
                     metrics=['accuracy'])

# %%
bigger_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_2 (Dense)             (None, 256)               200960
#
#  dense_3 (Dense)             (None, 256)               65792
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dense_5 (Dense)             (None, 128)               16512
#
#  dense_6 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 317,450
# Trainable params: 317,450
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = bigger_model.fit(train_dataset, 
                        epochs=N_EPOCHS, 
                        validation_data=test_dataset)
# Out:
# Epoch 1/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2487 - accuracy: 0.9250 - val_loss: 0.1196 - val_accuracy: 0.9619
# Epoch 2/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0944 - accuracy: 0.9709 - val_loss: 0.0859 - val_accuracy: 0.9739
# Epoch 3/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0631 - accuracy: 0.9804 - val_loss: 0.0871 - val_accuracy: 0.9737
# Epoch 4/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0497 - accuracy: 0.9840 - val_loss: 0.0778 - val_accuracy: 0.9784
# Epoch 5/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0410 - accuracy: 0.9866 - val_loss: 0.0814 - val_accuracy: 0.9768
# Epoch 6/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0325 - accuracy: 0.9891 - val_loss: 0.0873 - val_accuracy: 0.9754
# Epoch 7/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0287 - accuracy: 0.9906 - val_loss: 0.0783 - val_accuracy: 0.9772
# Epoch 8/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0257 - accuracy: 0.9917 - val_loss: 0.0918 - val_accuracy: 0.9753
# Epoch 9/20
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0223 - accuracy: 0.9926 - val_loss: 0.0830 - val_accuracy: 0.9794
# Epoch 10/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0217 - accuracy: 0.9930 - val_loss: 0.0725 - val_accuracy: 0.9811
# Epoch 11/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0153 - accuracy: 0.9952 - val_loss: 0.0852 - val_accuracy: 0.9807
# Epoch 12/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0159 - accuracy: 0.9949 - val_loss: 0.0852 - val_accuracy: 0.9805
# Epoch 13/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0153 - accuracy: 0.9951 - val_loss: 0.0909 - val_accuracy: 0.9791
# Epoch 14/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0132 - accuracy: 0.9956 - val_loss: 0.0926 - val_accuracy: 0.9776
# Epoch 15/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0173 - accuracy: 0.9944 - val_loss: 0.0728 - val_accuracy: 0.9809
# Epoch 16/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0114 - accuracy: 0.9965 - val_loss: 0.0835 - val_accuracy: 0.9820
# Epoch 17/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0133 - accuracy: 0.9960 - val_loss: 0.0897 - val_accuracy: 0.9808
# Epoch 18/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0093 - accuracy: 0.9972 - val_loss: 0.0899 - val_accuracy: 0.9790
# Epoch 19/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0113 - accuracy: 0.9963 - val_loss: 0.0916 - val_accuracy: 0.9805
# Epoch 20/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0119 - accuracy: 0.9963 - val_loss: 0.0877 - val_accuracy: 0.9801

# %%
plot_loss(N_EPOCHS, hist)

# %%
plot_accuracy(N_EPOCHS, hist)

# %% [markdown]
# ## Dropout 적용
# - layers.Dropout 객체를 이용
# - dropout rate는 0.2 ~ 0.5 정도로 설정
#     - 규제 강도는 rate를 크게 잡을 수록 커진다.
# - dropout node를 가질 Layer 앞에 추가.

# %%
def create_dropout_model():
    model = keras.Sequential()
    model.add(layers.Flatten(input_shape=(28,28)))
    
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(units=256, activation='relu'))
    
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(units=256, activation='relu'))
    
    model.add(layers.Dropout(0.3))
    model.add(layers.Dense(units=128, activation='relu'))
    
    model.add(layers.Dropout(0.3))
    model.add(layers.Dense(units=128, activation='relu'))
    
    model.add(layers.Dropout(0.3))
    model.add(layers.Dense(units=10, activation='softmax', name='output'))
    return model

# %%
dropout_model = create_dropout_model()
dropout_model.compile(optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE),
                      loss='categorical_crossentropy', 
                      metrics=['accuracy'])

# %%
dropout_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 784)               0
#
#  dropout (Dropout)           (None, 784)               0
#
#  dense_7 (Dense)             (None, 256)               200960
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_8 (Dense)             (None, 256)               65792
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_9 (Dense)             (None, 128)               32896
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_10 (Dense)            (None, 128)               16512
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  output (Dense)              (None, 10)                1290
#
# =================================================================
# Total params: 317,450
# Trainable params: 317,450
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Dropout Layer를 추가한 경우에는 epoch를 더 늘려준다.
hist = dropout_model.fit(train_dataset, 
                         epochs=N_EPOCHS+10, 
                         validation_data=test_dataset)
# Out:
# Epoch 1/30
# 600/600 [==============================] - 3s 4ms/step - loss: 0.8477 - accuracy: 0.7170 - val_loss: 0.2501 - val_accuracy: 0.9280
# Epoch 2/30
# 600/600 [==============================] - 3s 4ms/step - loss: 0.4386 - accuracy: 0.8701 - val_loss: 0.1758 - val_accuracy: 0.9504
# Epoch 3/30
# 600/600 [==============================] - 3s 4ms/step - loss: 0.3603 - accuracy: 0.8948 - val_loss: 0.1464 - val_accuracy: 0.9590
# Epoch 4/30
# 600/600 [==============================] - 2s 4ms/step - loss: 0.3258 - accuracy: 0.9057 - val_loss: 0.1285 - val_accuracy: 0.9626
# Epoch 5/30
# 600/600 [==============================] - 2s 4ms/step - loss: 0.3002 - accuracy: 0.9138 - val_loss: 0.1223 - val_accuracy: 0.9628
# Epoch 6/30
# 600/600 [==============================] - 3s 4ms/step - loss: 0.2805 - accuracy: 0.9186 - val_loss: 0.1088 - val_accuracy: 0.9668
# Epoch 7/30
# 600/600 [==============================] - 3s 4ms/step - loss: 0.2673 - accuracy: 0.9236 - val_loss: 0.1082 - val_accuracy: 0.9672
# Epoch 8/30
# 600/600 [==============================] - 2s 4ms/step - loss: 0.2561 - accuracy: 0.9269 - val_loss: 0.1003 - val_accuracy: 0.9712
# Epoch 9/30
# 600/600 [==============================] - 2s 4ms/step - loss: 0.2459 - accuracy: 0.9292 - val_loss: 0.1005 - val_accuracy: 0.9707
# Epoch 10/30
# 600/600 [==============================] - 3s 4ms/step - loss: 0.2401 - accuracy: 0.9298 - val_loss: 0.0925 - val_accuracy: 0.9746
# Epoch 11/30
# 600/600 [==============================] - 3s 4ms/step - loss: 0.2353 - accuracy: 0.9314 - val_loss: 0.1002 - val_accuracy: 0.9703
# Epoch 12/30
# 600/600 [==============================] - 2s 4ms/step - loss: 0.2291 - accuracy: 0.9347 - val_loss: 0.0942 - val_accuracy: 0.9737
# Epoch 13/30
# 600/600 [==============================] - 2s 4ms/step - loss: 0.2235 - accuracy: 0.9354 - val_loss: 0.0842 - val_accuracy: 0.9744
# Epoch 14/30
# 600/600 [==============================] - 3s 4ms/step - loss: 0.2171 - accuracy: 0.9363 - val_loss: 0.0907 - val_accuracy: 0.9743
# Epoch 15/30
# 600/600 [==============================] - 3s 5ms/step - loss: 0.2124 - accuracy: 0.9381 - val_loss: 0.0854 - val_accuracy: 0.9746
# Epoch 16/30
# 600/600 [==============================] - 2s 4ms/step - loss: 0.2155 - accuracy: 0.9366 - val_loss: 0.0866 - val_accuracy: 0.9742
# Epoch 17/30
# 600/600 [==============================] - 2s 4ms/step - loss: 0.2085 - accuracy: 0.9384 - val_loss: 0.0864 - val_accuracy: 0.9742
# Epoch 18/30
# 600/600 [==============================] - 3s 4ms/step - loss: 0.2077 - accuracy: 0.9394 - val_loss: 0.0820 - val_accuracy: 0.9765
# Epoch 19/30
# 600/600 [==============================] - 3s 5ms/step - loss: 0.2022 - accuracy: 0.9404 - val_loss: 0.0819 - val_accuracy: 0.9766
# Epoch 20/30
# 600/600 [==============================] - 3s 4ms/step - loss: 0.2073 - accuracy: 0.9401 - val_loss: 0.0812 - val_accuracy: 0.9763
# Epoch 21/30
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1999 - accuracy: 0.9421 - val_loss: 0.0820 - val_accuracy: 0.9765
# Epoch 22/30
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1998 - accuracy: 0.9416 - val_loss: 0.0838 - val_accuracy: 0.9740
# Epoch 23/30
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1976 - accuracy: 0.9420 - val_loss: 0.0815 - val_accuracy: 0.9773
# Epoch 24/30
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1988 - accuracy: 0.9423 - val_loss: 0.0769 - val_accuracy: 0.9785
# Epoch 25/30
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1912 - accuracy: 0.9439 - val_loss: 0.0821 - val_accuracy: 0.9767
# Epoch 26/30
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1865 - accuracy: 0.9457 - val_loss: 0.0744 - val_accuracy: 0.9778
# Epoch 27/30
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1927 - accuracy: 0.9447 - val_loss: 0.0790 - val_accuracy: 0.9768
# Epoch 28/30
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1856 - accuracy: 0.9472 - val_loss: 0.0832 - val_accuracy: 0.9767
# Epoch 29/30
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1821 - accuracy: 0.9467 - val_loss: 0.0773 - val_accuracy: 0.9779
# Epoch 30/30
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1854 - accuracy: 0.9459 - val_loss: 0.0755 - val_accuracy: 0.9776

# %%
plot_loss(N_EPOCHS+10, hist)

# %%
plot_accuracy(N_EPOCHS+10, hist)

# %% [markdown]
# ## Batch Normalization
# - Dense -> BN -> Activation  순서로 적용
# > Dense Layer: 가중합 처리 (X@W + B)
# > Dense(units=36) => 36개의 unit을 가지는 Dense Layer를 생성. 각 unit은 가중합 처리
# > Dense(units=36, activation='relu')  => 36개의 unit들이 가중합 처리하고 그 결과를 activation(relu) layer에 전달해서 처리. => Dense layer + Activation layer
# - layers.BatchNormalization 사용

# %%
layers.Softmax() # softmax
layers.Activation('sigmoid') # logistic(sigmoid)

# %%
def create_bn_model():
    model = keras.Sequential()
    model.add(layers.Flatten(input_shape=(28,28)))
    
    model.add(layers.Dense(units=256, name="my_dense")) # 가중합계산
    model.add(layers.BatchNormalization()) # Batch Normalization Layer - 평균: 0+beta, 표준편차: 1*gamma 의 분포
    model.add(layers.ReLU())  # activation Layer: ReLU
    
    # Dropout같이 사용하는 경우
    # Dropout - Dense - BatchNormalization - Activation
    model.add(layers.Dropout(0.3))
    model.add(layers.Dense(units=128))
    model.add(layers.BatchNormalization())
    model.add(layers.ReLU())
    
    # 출력
    model.add(layers.Dropout(0.3))
    model.add(layers.Dense(units=10))
    model.add(layers.BatchNormalization())
    model.add(layers.Softmax())
    
    return model

# %%
bn_model = create_bn_model()
bn_model.compile(optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE),
                 loss='categorical_crossentropy',
                 metrics=['accuracy'])

# %%
bn_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_3 (Flatten)         (None, 784)               0
#
#  my_dense (Dense)            (None, 256)               200960
#
#  batch_normalization (BatchN  (None, 256)              1024
#  ormalization)
#
#  re_lu (ReLU)                (None, 256)               0
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_11 (Dense)            (None, 128)               32896
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  re_lu_1 (ReLU)              (None, 128)               0
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_12 (Dense)            (None, 10)                1290
#
#  batch_normalization_2 (Batc  (None, 10)               40
#  hNormalization)
#
#  softmax_1 (Softmax)         (None, 10)                0
#
# =================================================================
# Total params: 236,722
# Trainable params: 235,934
# Non-trainable params: 788
# _________________________________________________________________

# %%
keras.utils.plot_model(bn_model, show_shapes=True)

# %%
hist = bn_model.fit(train_dataset, epochs=N_EPOCHS,
                    validation_data=test_dataset)
# Out:
# Epoch 1/20
# 600/600 [==============================] - 3s 4ms/step - loss: 0.5900 - accuracy: 0.8870 - val_loss: 0.2760 - val_accuracy: 0.9559
# Epoch 2/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2906 - accuracy: 0.9456 - val_loss: 0.1602 - val_accuracy: 0.9671
# Epoch 3/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2031 - accuracy: 0.9567 - val_loss: 0.1178 - val_accuracy: 0.9730
# Epoch 4/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1577 - accuracy: 0.9643 - val_loss: 0.0914 - val_accuracy: 0.9773
# Epoch 5/20
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1307 - accuracy: 0.9685 - val_loss: 0.0782 - val_accuracy: 0.9791
# Epoch 6/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1120 - accuracy: 0.9725 - val_loss: 0.0733 - val_accuracy: 0.9801
# Epoch 7/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0975 - accuracy: 0.9754 - val_loss: 0.0642 - val_accuracy: 0.9817
# Epoch 8/20
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0889 - accuracy: 0.9771 - val_loss: 0.0583 - val_accuracy: 0.9827
# Epoch 9/20
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0788 - accuracy: 0.9791 - val_loss: 0.0612 - val_accuracy: 0.9816
# Epoch 10/20
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0725 - accuracy: 0.9803 - val_loss: 0.0547 - val_accuracy: 0.9836
# Epoch 11/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0662 - accuracy: 0.9823 - val_loss: 0.0557 - val_accuracy: 0.9823
# Epoch 12/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0631 - accuracy: 0.9827 - val_loss: 0.0594 - val_accuracy: 0.9819
# Epoch 13/20
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0600 - accuracy: 0.9836 - val_loss: 0.0514 - val_accuracy: 0.9835
# Epoch 14/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0539 - accuracy: 0.9848 - val_loss: 0.0549 - val_accuracy: 0.9817
# Epoch 15/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0507 - accuracy: 0.9856 - val_loss: 0.0539 - val_accuracy: 0.9828
# Epoch 16/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0480 - accuracy: 0.9861 - val_loss: 0.0506 - val_accuracy: 0.9839
# Epoch 17/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0497 - accuracy: 0.9857 - val_loss: 0.0474 - val_accuracy: 0.9838
# Epoch 18/20
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0472 - accuracy: 0.9866 - val_loss: 0.0506 - val_accuracy: 0.9842
# Epoch 19/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0418 - accuracy: 0.9879 - val_loss: 0.0510 - val_accuracy: 0.9848
# Epoch 20/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0434 - accuracy: 0.9873 - val_loss: 0.0473 - val_accuracy: 0.9847

# %%
plot_loss(N_EPOCHS, hist)

# %%
plot_accuracy(N_EPOCHS, hist)

# %% [markdown]
# ## Learning Rate 조정을 이용한 성능향상
#
# ### Learning Rate Decay
# - 일정한 step마다 일정비율로 Learning rate를 조정

# %%
def create_model():
    model = keras.Sequential()
    model.add(layers.Flatten(input_shape=(28,28)))
    model.add(layers.Dense(units=256, activation='relu'))
    model.add(layers.Dense(units=128, activation='relu'))
    model.add(layers.Dense(units=128, activation='relu'))
    model.add(layers.Dense(units=10, activation='softmax'))
    return model

# %%
model = create_model()

# %%
# len(dataset객체) : epoch당 step수

len(train_dataset)*10  #10에폭의 step수
# Out:
# 6000

# %%
# 시작 Learning를 크게 잡아주고 갈수록  줄어들도록 규칙을 정한다. 
lr_scheduler = keras.optimizers.schedules.ExponentialDecay(
                    initial_learning_rate=LEARNING_RATE,  # 시작 Learning Rate
                    decay_steps=len(train_dataset)*5,     # 몇 step마다 변경할 것인지. (에폭단위가 아니라 step단위)
                    decay_rate=0.2,                       # 변경 비율. 현재_learning_rate * decay_rate => 새로운 learning rate
                    staircase=True,                       # 계단식변경 여부(defalt: False -> 매 스텝마다 조금씩 변경. True: 지정한 step에서 한번에 변경.)
                    )
# LearningRate Decay객체(ExponentialDecay)를 컴파일 할 때 설정하는 optimizer에 learinging_rate 매개변수에 전달.

# %%
#learning_rate에 LearningRate scheduler를 값(0.0001)대신 설정.
model.compile(optimizer=keras.optimizers.Adam(learning_rate=lr_scheduler),  
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
hist = model.fit(train_dataset, 
                 epochs=N_EPOCHS, 
                 validation_data=test_dataset)
# Out:
# Epoch 1/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2587 - accuracy: 0.9237 - val_loss: 0.1102 - val_accuracy: 0.9662
# Epoch 2/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0955 - accuracy: 0.9708 - val_loss: 0.0930 - val_accuracy: 0.9721
# Epoch 3/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0633 - accuracy: 0.9801 - val_loss: 0.0834 - val_accuracy: 0.9756
# Epoch 4/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0456 - accuracy: 0.9855 - val_loss: 0.0852 - val_accuracy: 0.9750
# Epoch 5/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0332 - accuracy: 0.9893 - val_loss: 0.0757 - val_accuracy: 0.9800
# Epoch 6/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0125 - accuracy: 0.9965 - val_loss: 0.0621 - val_accuracy: 0.9838
# Epoch 7/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0073 - accuracy: 0.9983 - val_loss: 0.0641 - val_accuracy: 0.9828
# Epoch 8/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0053 - accuracy: 0.9989 - val_loss: 0.0680 - val_accuracy: 0.9827
# Epoch 9/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0038 - accuracy: 0.9994 - val_loss: 0.0678 - val_accuracy: 0.9833
# Epoch 10/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0030 - accuracy: 0.9994 - val_loss: 0.0760 - val_accuracy: 0.9818
# Epoch 11/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0016 - accuracy: 0.9999 - val_loss: 0.0700 - val_accuracy: 0.9836
# Epoch 12/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0013 - accuracy: 0.9999 - val_loss: 0.0707 - val_accuracy: 0.9837
# Epoch 13/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0011 - accuracy: 0.9999 - val_loss: 0.0712 - val_accuracy: 0.9836
# Epoch 14/20
# 600/600 [==============================] - 2s 3ms/step - loss: 9.7839e-04 - accuracy: 1.0000 - val_loss: 0.0732 - val_accuracy: 0.9837
# Epoch 15/20
# 600/600 [==============================] - 2s 3ms/step - loss: 8.8143e-04 - accuracy: 0.9999 - val_loss: 0.0747 - val_accuracy: 0.9836
# Epoch 16/20
# 600/600 [==============================] - 2s 3ms/step - loss: 7.1778e-04 - accuracy: 1.0000 - val_loss: 0.0745 - val_accuracy: 0.9841
# Epoch 17/20
# 600/600 [==============================] - 2s 3ms/step - loss: 6.8838e-04 - accuracy: 1.0000 - val_loss: 0.0745 - val_accuracy: 0.9841
# Epoch 18/20
# 600/600 [==============================] - 2s 3ms/step - loss: 6.6380e-04 - accuracy: 1.0000 - val_loss: 0.0750 - val_accuracy: 0.9837
# Epoch 19/20
# 600/600 [==============================] - 2s 3ms/step - loss: 6.4172e-04 - accuracy: 1.0000 - val_loss: 0.0752 - val_accuracy: 0.9839
# Epoch 20/20
# 600/600 [==============================] - 2s 3ms/step - loss: 6.1264e-04 - accuracy: 1.0000 - val_loss: 0.0756 - val_accuracy: 0.9838

# %%
plot_loss(N_EPOCHS, hist)

# %% [markdown]
# ### Callback 을 이용한 학습률 조정
# - ReduceLROnPlateau callback을 이용
#     - 학습시 성능이 개선이 안되는 경우 LR를 조정

# %%
model = create_model()
model.compile(optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# ReduceLROnPlateau: 학습도중에 성능이 개선이 되지 않으면(시점) Learning Rate를 조정(처리)
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint

lr_cb = ReduceLROnPlateau(monitor='val_loss',  # 어떤 성능 확인할 지 (default: val_loss)
                          factor=0.2,          # 변경비율 (현재 LR * factor => 새로운 LR)
                          patience=3,          # 성능개선이 안되는 것을 몇 epoch까지 볼것인지. 설정한 에폭 안에 성능 개선이 안되면 LR를 변경.(보통 5, 10)
                          verbose=2) # 로그(기록) 출력

# %%
# callback은 fit() 메소드의 callbacks 매개변수에 리스트에 담아서 전달.
hist = model.fit(train_dataset, epochs=N_EPOCHS, 
                 validation_data=test_dataset,
                 callbacks=[lr_cb])
# Out:
# Epoch 1/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2498 - accuracy: 0.9271 - val_loss: 0.1101 - val_accuracy: 0.9663 - lr: 0.0010
# Epoch 2/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0934 - accuracy: 0.9718 - val_loss: 0.0943 - val_accuracy: 0.9708 - lr: 0.0010
# Epoch 3/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0608 - accuracy: 0.9808 - val_loss: 0.0776 - val_accuracy: 0.9758 - lr: 0.0010
# Epoch 4/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0450 - accuracy: 0.9850 - val_loss: 0.0683 - val_accuracy: 0.9790 - lr: 0.0010
# Epoch 5/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0342 - accuracy: 0.9886 - val_loss: 0.0792 - val_accuracy: 0.9766 - lr: 0.0010
# Epoch 6/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0271 - accuracy: 0.9909 - val_loss: 0.0770 - val_accuracy: 0.9779 - lr: 0.0010
# Epoch 7/20
# 583/600 [============================>.] - ETA: 0s - loss: 0.0264 - accuracy: 0.9914
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0265 - accuracy: 0.9913 - val_loss: 0.0767 - val_accuracy: 0.9776 - lr: 0.0010
# Epoch 8/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0080 - accuracy: 0.9975 - val_loss: 0.0606 - val_accuracy: 0.9846 - lr: 2.0000e-04
# Epoch 9/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0034 - accuracy: 0.9993 - val_loss: 0.0612 - val_accuracy: 0.9844 - lr: 2.0000e-04
# Epoch 10/20
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.0634 - val_accuracy: 0.9851 - lr: 2.0000e-04
# Epoch 11/20
# 588/600 [============================>.] - ETA: 0s - loss: 0.0014 - accuracy: 0.9998
# Epoch 11: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 0.0665 - val_accuracy: 0.9853 - lr: 2.0000e-04
# Epoch 12/20
# 600/600 [==============================] - 2s 3ms/step - loss: 8.2377e-04 - accuracy: 0.9999 - val_loss: 0.0664 - val_accuracy: 0.9853 - lr: 4.0000e-05
# Epoch 13/20
# 600/600 [==============================] - 2s 4ms/step - loss: 6.7279e-04 - accuracy: 1.0000 - val_loss: 0.0670 - val_accuracy: 0.9856 - lr: 4.0000e-05
# Epoch 14/20
# 592/600 [============================>.] - ETA: 0s - loss: 5.9357e-04 - accuracy: 1.0000
# Epoch 14: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 600/600 [==============================] - 3s 4ms/step - loss: 5.9484e-04 - accuracy: 1.0000 - val_loss: 0.0678 - val_accuracy: 0.9856 - lr: 4.0000e-05
# Epoch 15/20
# 600/600 [==============================] - 2s 3ms/step - loss: 5.1397e-04 - accuracy: 1.0000 - val_loss: 0.0679 - val_accuracy: 0.9857 - lr: 8.0000e-06
# Epoch 16/20
# 600/600 [==============================] - 2s 3ms/step - loss: 4.9776e-04 - accuracy: 1.0000 - val_loss: 0.0680 - val_accuracy: 0.9856 - lr: 8.0000e-06
# Epoch 17/20
# 589/600 [============================>.] - ETA: 0s - loss: 4.8429e-04 - accuracy: 1.0000
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 600/600 [==============================] - 2s 3ms/step - loss: 4.8112e-04 - accuracy: 1.0000 - val_loss: 0.0683 - val_accuracy: 0.9855 - lr: 8.0000e-06
# Epoch 18/20
# 600/600 [==============================] - 2s 3ms/step - loss: 4.5648e-04 - accuracy: 1.0000 - val_loss: 0.0684 - val_accuracy: 0.9854 - lr: 1.6000e-06
# Epoch 19/20
# 600/600 [==============================] - 2s 3ms/step - loss: 4.5189e-04 - accuracy: 1.0000 - val_loss: 0.0685 - val_accuracy: 0.9855 - lr: 1.6000e-06
# Epoch 20/20
# 589/600 [============================>.] - ETA: 0s - loss: 4.4672e-04 - accuracy: 1.0000
# Epoch 20: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 600/600 [==============================] - 2s 3ms/step - loss: 4.4677e-04 - accuracy: 1.0000 - val_loss: 0.0686 - val_accuracy: 0.9855 - lr: 1.6000e-06
